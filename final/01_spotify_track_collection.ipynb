# %% [markdown]
# # Step 1 | Collect track data by music genre

# %% [markdown]
# The main objective of this notebook is to retrieve **generic features** (e.g. *popularity*, *artist*) as well as the main **11 Spotify audio features** (i.e. *danceability*, *energy*, *key*, *loudness*, *mode*, *speechiness*, *acousticness*, *instrumentalness*, *liveness*, *valence*, *tempo*) characterizing a **track**.
#
# The scope of this model will be limited to the music genres that, in line with the study on [Individual Differences in Musical Taste](https://www.jstor.org/stable/10.5406/amerjpsyc.123.2.0199), can be mapped to different personalities or moods.
#
# It's important to note that in the Spotify API genres are attributed to artists and not playlists. Therefore, in order to obtain a list of tracks belonging to a specific music genre, we need to start from the artist. It's clear that the representative music genre of an artist could be both varied or even change over time. For the purpose of simplifying the analysis for this initial prototype, we will attribute only one genre to each artist and we will assume that every album and track belonging to that artist will be characterized by the same music genre.

# %% [markdown]
# ----
#
# The **algorithm** will be developed according to three main steps:
# 1. Get a list of **<mark>artists<mark/>** belonging to the music genres in scope
# 2. Retrieve a list of **<mark>albums<mark/>** for the artists identified in the previous step
# 3. Retrieve the list of **<mark>tracks<mark/>** included in the albums identified in pt 2 above
#
# ----

# %%
# imports
import json
import spotipy
import spotipy.util as util
import pandas as pd
import pickle
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# retrieve client id and client secret from txt file saved locally
file = '/Users/valentinarizzati/Desktop/GitStuff/Projects/Engineering-Spotify/final/spotify_creds.txt'

with open(file,'r') as f: 
    f = f.read().splitlines()
    cid = f[0].split(':')[1]
    secret = f[1].split(':')[1]

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

# initiate spotipy client
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Initial EDA

# %%
# function to obtain artist's genre
def get_artist_genre(artist):
    result = sp.search(artist)
    track = result['tracks']['items'][0]

    artist = sp.artist(track['artists'][0]['external_urls']['spotify'])
    print("artist genres:", artist["genres"])

# %% [markdown]
# Let's now do some spotipy testing across a few music genres in Spotify.

# %%
# expect jazz/soul
get_artist_genre('Nina Simone')
# Out:
# artist genres: ['jazz blues', 'soul', 'soul jazz', 'torch song', 'vocal jazz']

# %%
# expect rock/metal
get_artist_genre('Nirvana')
# Out:
# artist genres: ['alternative rock', 'grunge', 'permanent wave', 'rock']

# %%
# expect rap/hip hop
get_artist_genre('2Pac')
# Out:
# artist genres: ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']

# %%
# expect pop
get_artist_genre('Sia')
# Out:
# artist genres: ['australian dance', 'australian pop', 'pop']

# %%
# expect classical
get_artist_genre('Mozart')
# Out:
# artist genres: ['classical', 'classical era']

# %%
# expect dance/house
get_artist_genre('Avicii')
# Out:
# artist genres: ['dance pop', 'edm', 'pop', 'pop dance']

# %%
# expect electronic
get_artist_genre('Gramatik')
# Out:
# artist genres: ['downtempo', 'jazz boom bap', 'jazztronica', 'livetronica', 'nu jazz', 'slovenian electronic', 'trip hop']

# %%
# expect electronic
get_artist_genre('De Hofnar')
# Out:
# artist genres: ['tropical house']

# %%
# expect electronic
get_artist_genre('Moderat')
# Out:
# artist genres: ['environmental']

# %%
# expect electronic
get_artist_genre('Max Manie')
# Out:
# artist genres: ['deep tropical house', 'tropical house']

# %%
# expect pop
get_artist_genre('Billie Eilish')
# Out:
# artist genres: ['electropop', 'pop']

# %% [markdown]
# ----
#
# As we see from the testing above, **genre labeling is definitely not a perfect science** on the Spotify platform. Particularly, we notice that:<br/>
# 1. Most artists have more than one genre associated with their music.
# 2. A few artists present genres that are not in accordance with the popular definition.
#     - This is especially true for the music genre *electronic*, that is commonly identified in Spotify as *tropical house* or *environmental*.
#
# ----

# %% [markdown]
# ## Retrieve tracks across 15 music genres

# %% [markdown]
# ## 1. Artists by Genre

# %% [markdown]
# As a first step, we will find a list of artists belonging to the main music genres mentioned in the study. For this purpose, we will create a function that will streamline and automate the pipeline going forward.

# %%
# define list of music genres we can map to moods/personalities
seed_genres = ['pop',
               'rap',
               'r&b', 
               'country',
               'rock',
               'metal', 
               'indie',
               'dance',  
               'edm', 
               'classical',
               'jazz',
               'blues',
               'soul',
               'electronic',
               'house'
              ]

# %%
len(seed_genres)
# Out:
# 15

# %%
limit = 50

artists_one_genre = {} # mapping artists to a single genre
artists = {} # mapping artists to a genre for multiple genres

def get_artists_by_genre(genre):
    '''
    Given a music genre, return a list of 500
    artists that are characterized by that genre.
    Then attribute only one genre to a specific artist.
    '''
    for i in range(0,500,50): # offset set to 500 because we want to get 500 artists per genre
        artist_results = sp.search(q='genre:'+str(genre), type='artist',limit=limit,offset=i) 
        for j in range(0,limit):
            name = artist_results['artists']['items'][j]['name']
            artists[name] = genre
            artists_one_genre[name] = genre
            
    pass

def get_all_artists(genre_list):
    '''
    Given a list of genres, return a list of artists by genre.
    Then attribute only one genre to a specific artist.
    Save results to a dictionary.
    '''
    for genre in genre_list:
        get_artists_by_genre(genre)
        print("Pulled {0} artists from the {1} genre".format(len(artists_one_genre), genre))
        artists_one_genre.clear()
    
    
    print("\nPulled a total of {0} artists across {1} genres".format(len(artists), len(seed_genres)))
    return artists

# %%
get_all_artists(seed_genres)
# Out:
# Pulled 499 artists from the pop genre
# Pulled 499 artists from the rap genre
# Pulled 500 artists from the r&b genre
# Pulled 500 artists from the country genre
# Pulled 499 artists from the rock genre
# Pulled 500 artists from the metal genre
# Pulled 500 artists from the indie genre
# Pulled 500 artists from the dance genre
# Pulled 499 artists from the edm genre
# Pulled 498 artists from the classical genre
# Pulled 499 artists from the jazz genre
# Pulled 500 artists from the blues genre
# Pulled 500 artists from the soul genre
# Pulled 500 artists from the electronic genre
# Pulled 500 artists from the house genre
#
# Pulled a total of 5267 artists across 15 genres
# {'Drake': 'rap',
#  'Olivia Rodrigo': 'pop',
#  'Doja Cat': 'dance',
#  'Taylor Swift': 'pop',
#  'Justin Bieber': 'pop',
#  'The Weeknd': 'r&b',
#  'Ariana Grande': 'dance',
#  'BTS': 'pop',
#  'Nicki Minaj': 'dance',
#  'Lil Wayne': 'rap',
#  'Chris Brown': 'dance',
#  'Dua Lipa': 'dance',
#  'SZA': 'r&b',
#  'Bruno Mars': 'dance',
#  'Khalid': 'pop',
#  'Megan Thee Stallion': 'rap',
#  'Rihanna': 'dance',
#  'Future': 'rap',
#  'Billie Eilish': 'pop',
#  'Ed Sheeran': 'pop',
#  'Young Thug': 'rap',
#  'Ty Dolla $ign': 'soul',
#  'Migos': 'rap',
#  'Machine Gun Kelly': 'rap',
#  'Maroon 5': 'rock',
#  'Cardi B': 'dance',
#  'blackbear': 'rock',
#  'Halsey': 'dance',
#  'Marshmello': 'house',
#  'Kali Uchis': 'pop',
#  'Wiz Khalifa': 'dance',
#  'Beyoncé': 'dance',
#  'Rauw Alejandro': 'pop',
#  'Giveon': 'r&b',
#  'A Boogie Wit da Hoodie': 'rap',
#  'Harry Styles': 'pop',
#  'Miley Cyrus': 'dance',
#  'Lady Gaga': 'dance',
#  'NF': 'rap',
#  'Glass Animals': 'indie',
#  'Florida Georgia Line': 'rock',
#  'Ozuna': 'pop',
#  'JAY-Z': 'rap',
#  'One Direction': 'pop',
#  'Jhené Aiko': 'dance',
#  'David Guetta': 'edm',
#  'Kid Cudi': 'rap',
#  'Lana Del Rey': 'pop',
#  'Katy Perry': 'dance',
#  'Frank Ocean': 'soul',
#  'Calvin Harris': 'house',
#  'Imagine Dragons': 'rock',
#  'H.E.R.': 'dance',
#  'Demi Lovato': 'dance',
#  'Lil Nas X': 'rap',
#  'Pitbull': 'dance',
#  'Big Sean': 'rap',
#  'Shawn Mendes': 'dance',
#  'Daniel Caesar': 'r&b',
#  'WILLOW': 'dance',
#  'iann dior': 'rap',
#  'Logic': 'rap',
#  'Tyga': 'dance',
#  'T-Pain': 'dance',
#  'Coldplay': 'pop',
#  'The Neighbourhood': 'rock',
#  'Diplo': 'house',
#  'Russ': 'rap',
#  'P!nk': 'dance',
#  'Miguel': 'dance',
#  'Brent Faiyaz': 'r&b',
#  'Tory Lanez': 'r&b',
#  'Lorde': 'dance',
#  'Joji': 'r&b',
#  'Kehlani': 'dance',
#  'Metro Boomin': 'rap',
#  'Sam Smith': 'dance',
#  'Britney Spears': 'dance',
#  'Selena Gomez': 'dance',
#  'John Mayer': 'rock',
#  'Panic! At The Disco': 'rock',
#  'Paramore': 'pop',
#  'Saweetie': 'dance',
#  'G-Eazy': 'indie',
#  'Clairo': 'indie',
#  'Usher': 'dance',
#  'DJ Khaled': 'rap',
#  'Jonas Brothers': 'dance',
#  'Mitski': 'indie',
#  'Tate McRae': 'dance',
#  'Jack Harlow': 'rap',
#  'OneRepublic': 'dance',
#  '2 Chainz': 'rap',
#  'Justin Timberlake': 'dance',
#  'Fall Out Boy': 'rock',
#  'Pharrell Williams': 'rap',
#  'Snoop Dogg': 'rap',
#  'Jason Derulo': 'dance',
#  'Sia': 'dance',
#  'AJR': 'rock',
#  'The Chainsmokers': 'house',
#  'Gucci Mane': 'rap',
#  'Offset': 'rap',
#  'Kygo': 'house',
#  'Internet Money': 'rap',
#  'Bryson Tiller': 'r&b',
#  'Jeremih': 'dance',
#  'Chance the Rapper': 'rap',
#  'Bebe Rexha': 'dance',
#  '5 Seconds of Summer': 'dance',
#  'Rick Ross': 'rap',
#  'Quinn XCII': 'indie',
#  'Michael Jackson': 'soul',
#  'Dan + Shay': 'country',
#  'blink-182': 'pop',
#  'Meek Mill': 'rap',
#  'Quavo': 'rap',
#  'Rex Orange County': 'pop',
#  'Nelly': 'dance',
#  'Kesha': 'dance',
#  'PARTYNEXTDOOR': 'r&b',
#  'Julia Michaels': 'dance',
#  '6LACK': 'r&b',
#  'Niall Horan': 'dance',
#  'Akon': 'dance',
#  'Måneskin': 'indie',
#  'Melanie Martinez': 'dance',
#  'Lewis Capaldi': 'pop',
#  'Ne-Yo': 'dance',
#  'James Arthur': 'pop',
#  'Sam Hunt': 'country',
#  'Conan Gray': 'indie',
#  'Camila Cabello': 'dance',
#  'Green Day': 'pop',
#  'Cavetown': 'indie',
#  'ILLENIUM': 'house',
#  'MARINA': 'dance',
#  'Shakira': 'dance',
#  'Adele': 'soul',
#  'Sech': 'pop',
#  'Black Eyed Peas': 'dance',
#  'Summer Walker': 'r&b',
#  'Childish Gambino': 'rap',
#  'NAV': 'rap',
#  'girl in red': 'indie',
#  'Lauv': 'dance',
#  'Flo Rida': 'dance',
#  'Lil Skies': 'rap',
#  'Surfaces': 'soul',
#  'YG': 'rap',
#  'Ava Max': 'dance',
#  'City Girls': 'dance',
#  'Avicii': 'edm',
#  'Bazzi': 'dance',
#  'Weezer': 'rock',
#  'T.I.': 'dance',
#  'Hozier': 'rock',
#  'My Chemical Romance': 'pop',
#  'Little Mix': 'dance',
#  '50 Cent': 'rap',
#  'Troye Sivan': 'dance',
#  'Trey Songz': 'dance',
#  'John Legend': 'soul',
#  'Joyner Lucas': 'rap',
#  'Wale': 'dance',
#  'Tiësto': 'house',
#  'Ellie Goulding': 'edm',
#  'TWICE': 'pop',
#  'BLACKPINK': 'pop',
#  'Mother Mother': 'indie',
#  'Jeremy Zucker': 'pop',
#  'Charlie Puth': 'dance',
#  'Bas': 'rap',
#  'Zedd': 'house',
#  'Ludacris': 'rap',
#  'Vance Joy': 'rock',
#  'Lizzo': 'dance',
#  'Galantis': 'house',
#  'Kelsea Ballerini': 'country',
#  'Mariah Carey': 'dance',
#  'Labrinth': 'indie',
#  'Becky G': 'dance',
#  'Alicia Keys': 'soul',
#  'Madison Beer': 'dance',
#  'All Time Low': 'rock',
#  'LANY': 'pop',
#  'Chase Atlantic': 'rock',
#  'Bryce Vine': 'rap',
#  'The Lumineers': 'rock',
#  'Mustard': 'rap',
#  'Christina Aguilera': 'dance',
#  'The Beach Boys': 'rock',
#  'ZAYN': 'dance',
#  'DJ Snake': 'electronic',
#  'Chelsea Cutler': 'indie',
#  'benny blanco': 'rap',
#  'Alessia Cara': 'dance',
#  'B.o.B': 'dance',
#  'Skrillex': 'edm',
#  'Phoebe Bridgers': 'indie',
#  'Train': 'dance',
#  'Avril Lavigne': 'dance',
#  'Wallows': 'indie',
#  'Anne-Marie': 'house',
#  'TOMORROW X TOGETHER': 'pop',
#  'Selena': 'pop',
#  'Meghan Trainor': 'dance',
#  'Sean Paul': 'dance',
#  'Gwen Stefani': 'dance',
#  'Andy Grammer': 'dance',
#  'Dominic Fike': 'rock',
#  'Keith Urban': 'country',
#  'Jaden': 'rap',
#  'Gryffin': 'house',
#  'Whitney Houston': 'dance',
#  'Timbaland': 'dance',
#  'Camilo': 'pop',
#  'French Montana': 'rap',
#  'Kelly Clarkson': 'dance',
#  'Missy Elliott': 'dance',
#  'Tech N9ne': 'rap',
#  'Ashnikko': 'pop',
#  'ScHoolboy Q': 'rap',
#  'Noah Cyrus': 'dance',
#  'Bastille': 'house',
#  'A$AP Ferg': 'rap',
#  'ABBA': 'pop',
#  'Flo Milli': 'dance',
#  'Major Lazer': 'house',
#  'Martin Garrix': 'house',
#  'Alec Benjamin': 'pop',
#  'Tove Lo': 'dance',
#  'Kacey Musgraves': 'country',
#  'Mark Ronson': 'soul',
#  'Carrie Underwood': 'country',
#  'Charli XCX': 'dance',
#  'Ella Mai': 'dance',
#  'Jennifer Lopez': 'dance',
#  'Mike Posner': 'dance',
#  'PnB Rock': 'r&b',
#  'Rascal Flatts': 'rock',
#  'R3HAB': 'house',
#  'Ciara': 'dance',
#  'Beach Bunny': 'indie',
#  'The 1975': 'rock',
#  'Enrique Iglesias': 'dance',
#  'Steve Aoki': 'house',
#  'Alan Walker': 'house',
#  "Destiny's Child": 'dance',
#  'Still Woozy': 'indie',
#  "Olivia O'Brien": 'dance',
#  'MAX': 'dance',
#  'Cheat Codes': 'house',
#  'Louis The Child': 'house',
#  'Mary J. Blige': 'soul',
#  'Zara Larsson': 'house',
#  'Juicy J': 'rap',
#  'SAINt JHN': 'house',
#  'X Ambassadors': 'indie',
#  'Ricky Montgomery': 'indie',
#  'Lady A': 'rock',
#  'Tai Verdes': 'indie',
#  'Hailee Steinfeld': 'dance',
#  'YUNGBLUD': 'indie',
#  'Diddy': 'dance',
#  'will.i.am': 'dance',
#  'A Day To Remember': 'metal',
#  'Lord Huron': 'indie',
#  'Lil Jon': 'dance',
#  'Nelly Furtado': 'dance',
#  'Rico Nasty': 'dance',
#  'NEEDTOBREATHE': 'indie',
#  'Tainy': 'pop',
#  'Aminé': 'rap',
#  'KYLE': 'rap',
#  'Nate Dogg': 'rap',
#  'Iggy Azalea': 'dance',
#  'Florence + The Machine': 'pop',
#  'Madonna': 'dance',
#  'Rae Sremmurd': 'rap',
#  'Chief Keef': 'rap',
#  'Sam Feldt': 'house',
#  'Cuco': 'pop',
#  'Jon Bellion': 'rap',
#  'Jason Mraz': 'rock',
#  'Disclosure': 'house',
#  'Tones And I': 'pop',
#  'Stray Kids': 'pop',
#  'Jacquees': 'dance',
#  'Beach House': 'indie',
#  'JP Saxe': 'indie',
#  'AURORA': 'pop',
#  'DMX': 'rap',
#  'Rich The Kid': 'rap',
#  'Willie Nelson': 'rock',
#  'Imanbek': 'house',
#  'Alesso': 'house',
#  'Marc Anthony': 'pop',
#  'Foster The People': 'indie',
#  'The All-American Rejects': 'rock',
#  'beabadoobee': 'indie',
#  'Pearl Jam': 'rock',
#  'Daya': 'house',
#  'Don Omar': 'pop',
#  'Natti Natasha': 'rap',
#  'Fetty Wap': 'rap',
#  'Sebastian Yatra': 'pop',
#  'Reik': 'pop',
#  'Wilbur Soot': 'pop',
#  'Tinashe': 'dance',
#  'Yo Gotti': 'rap',
#  'Ashanti': 'dance',
#  'Dermot Kennedy': 'pop',
#  'Busta Rhymes': 'rap',
#  'Gym Class Heroes': 'dance',
#  'Bea Miller': 'dance',
#  'The Offspring': 'metal',
#  'FINNEAS': 'indie',
#  'Falling In Reverse': 'metal',
#  'WizKid': 'dance',
#  'Joel Corry': 'house',
#  'Neon Trees': 'rock',
#  'Ashe': 'indie',
#  'Sasha Sloan': 'indie',
#  'Clean Bandit': 'house',
#  'Macklemore': 'rap',
#  'Nipsey Hussle': 'rap',
#  'Jeezy': 'rap',
#  'Cordae': 'rap',
#  'Sleeping At Last': 'indie',
#  'Prince Royce': 'pop',
#  'Latto': 'r&b',
#  'bbno$': 'rap',
#  'Regard': 'house',
#  'Pink Sweat$': 'soul',
#  'COIN': 'indie',
#  'Lunay': 'pop',
#  'Oh Wonder': 'indie',
#  'Fabolous': 'dance',
#  'Manuel Turizo': 'pop',
#  'Eyedress': 'pop',
#  'Marc E. Bassy': 'r&b',
#  "Why Don't We": 'dance',
#  'Dean Lewis': 'indie',
#  'Gabby Barrett': 'country',
#  'Dolly Parton': 'country',
#  'Yung Bleu': 'r&b',
#  'Shania Twain': 'dance',
#  'Ben Platt': 'pop',
#  'Backstreet Boys': 'dance',
#  'Carly Rae Jepsen': 'dance',
#  'Dayglow': 'indie',
#  'Loud Luxury': 'house',
#  'Luis Fonsi': 'pop',
#  'Maná': 'rock',
#  'BØRNS': 'rock',
#  'Sara Bareilles': 'dance',
#  'mxmtoon': 'indie',
#  'Anitta': 'pop',
#  'Cigarettes After Sex': 'indie',
#  'Jonas Blue': 'house',
#  'Penelope Scott': 'indie',
#  'Michael Bublé': 'jazz',
#  'Pierce The Veil': 'rock',
#  'Jazmine Sullivan': 'soul',
#  'Maria Becerra': 'pop',
#  'Sabrina Carpenter': 'dance',
#  'Jessie Reyez': 'dance',
#  'Dave Matthews Band': 'rock',
#  'Fergie': 'dance',
#  'EXO': 'pop',
#  'Owl City': 'indie',
#  'The Script': 'dance',
#  'Sean Kingston': 'dance',
#  'Topic': 'house',
#  'Jess Glynne': 'house',
#  'RAYE': 'house',
#  'Rise Against': 'pop',
#  'Fitz and The Tantrums': 'indie',
#  'The Marías': 'indie',
#  'Luis Miguel': 'pop',
#  'SLANDER': 'electronic',
#  'Hollywood Undead': 'metal',
#  'Vampire Weekend': 'indie',
#  'Yelawolf': 'rap',
#  'Grouplove': 'indie',
#  'TLC': 'dance',
#  'Aventura': 'pop',
#  'Rita Ora': 'house',
#  'Lovejoy': 'indie',
#  'Nick Jonas': 'dance',
#  'FLETCHER': 'dance',
#  'Soulja Boy': 'dance',
#  'Lennon Stella': 'dance',
#  'Queen Naija': 'dance',
#  'The Band CAMINO': 'indie',
#  'Ali Gatie': 'pop',
#  'Eric Bellinger': 'dance',
#  'Maggie Rogers': 'indie',
#  'Arizona Zervas': 'rap',
#  'The Fray': 'rock',
#  'Current Joys': 'indie',
#  '3 Doors Down': 'metal',
#  'WALK THE MOON': 'dance',
#  'The Game': 'rap',
#  'Ryan Hurd': 'country',
#  'Ruel': 'indie',
#  'Jimmy Eat World': 'rock',
#  'The Smashing Pumpkins': 'metal',
#  'Sam Fischer': 'dance',
#  'Ja Rule': 'dance',
#  'Alina Baraz': 'r&b',
#  'Anson Seabra': 'indie',
#  'Toosii': 'r&b',
#  'Tori Kelly': 'dance',
#  'MKTO': 'dance',
#  'mike.': 'indie',
#  'MEDUZA': 'house',
#  'Robin Schulz': 'house',
#  'K CAMP': 'r&b',
#  'Tom Petty and the Heartbreakers': 'rock',
#  'Afrojack': 'house',
#  'SEVENTEEN': 'pop',
#  'HAIM': 'dance',
#  'Keyshia Cole': 'soul',
#  'Sigala': 'house',
#  'BENEE': 'pop',
#  'E-40': 'rap',
#  'Carly Pearce': 'country',
#  'Ruth B.': 'indie',
#  'Jorja Smith': 'r&b',
#  'James Bay': 'rock',
#  'Lauren Alaina': 'rock',
#  'Of Monsters and Men': 'indie',
#  'Lloyd': 'dance',
#  'Macklemore & Ryan Lewis': 'rock',
#  'keshi': 'r&b',
#  'Colbie Caillat': 'dance',
#  'Noah Kahan': 'indie',
#  'Christina Perri': 'dance',
#  'Lukas Graham': 'pop',
#  'Duncan Laurence': 'pop',
#  'Bleachers': 'indie',
#  'fun.': 'rock',
#  'Glee Cast': 'pop',
#  'Adam Levine': 'rock',
#  'MØ': 'house',
#  'Tom Petty': 'rock',
#  'Zendaya': 'dance',
#  '*NSYNC': 'dance',
#  'Trevor Daniel': 'r&b',
#  'NOTD': 'house',
#  'Shaggy': 'dance',
#  'Jay Rock': 'rap',
#  'Kid Ink': 'dance',
#  'Milky Chance': 'pop',
#  'Young the Giant': 'indie',
#  'Jimmie Allen': 'country',
#  'Modest Mouse': 'indie',
#  'Ricky Martin': 'dance',
#  'Tom Grennan': 'rock',
#  'Zac Efron': 'dance',
#  'Calum Scott': 'indie',
#  'Bryan Adams': 'rock',
#  'Two Feet': 'indie',
#  'TV Girl': 'indie',
#  'Ms. Lauryn Hill': 'soul',
#  'Matchbox Twenty': 'rock',
#  'LOONA': 'pop',
#  'The Head And The Heart': 'indie',
#  'Dance Gavin Dance': 'indie',
#  'Young M.A': 'rap',
#  'Grimes': 'dance',
#  'Jamie Foxx': 'soul',
#  'Lemon Demon': 'indie',
#  'Jessie J': 'dance',
#  'Snoh Aalegra': 'soul',
#  'Ludovico Einaudi': 'classical',
#  'Walker Hayes': 'rock',
#  'Tears For Fears': 'rock',
#  'Kiana Ledé': 'dance',
#  'Burna Boy': 'dance',
#  'Normani': 'dance',
#  'Clinton Kane': 'indie',
#  'Kim Petras': 'dance',
#  'Remi Wolf': 'indie',
#  'Hopsin': 'rap',
#  'Céline Dion': 'dance',
#  'Pusha T': 'rap',
#  'Fifth Harmony': 'dance',
#  'John Denver': 'rock',
#  'Quality Control': 'rap',
#  'Becky Hill': 'house',
#  'Matoma': 'house',
#  'Sum 41': 'metal',
#  'Alejandro Fernández': 'pop',
#  'Electric Light Orchestra': 'rock',
#  'Cash Cash': 'house',
#  'The Pussycat Dolls': 'dance',
#  'Juice WRLD': 'rap',
#  'Lil Baby': 'rap',
#  'Polo G': 'rap',
#  'Lil Uzi Vert': 'rap',
#  'Kanye West': 'rap',
#  'Tyler, The Creator': 'rap',
#  'Post Malone': 'rap',
#  'DaBaby': 'rap',
#  'Travis Scott': 'house',
#  'Lil Durk': 'rap',
#  'J. Cole': 'rap',
#  'Gunna': 'rap',
#  'Trippie Redd': 'rap',
#  'Eminem': 'rap',
#  'YoungBoy Never Broke Again': 'rap',
#  'Kendrick Lamar': 'rap',
#  'Mac Miller': 'rap',
#  'XXXTENTACION': 'rap',
#  'Roddy Ricch': 'rap',
#  '21 Savage': 'rap',
#  'Lil Tjay': 'rap',
#  'Playboi Carti': 'rap',
#  'Kodak Black': 'rap',
#  '$uicideboy$': 'rap',
#  'Don Toliver': 'rap',
#  'Lil Peep': 'rap',
#  'Rod Wave': 'rap',
#  'Moneybagg Yo': 'rap',
#  'Kevin Gates': 'rap',
#  'Lil Yachty': 'rap',
#  'Lil Tecca': 'rap',
#  'A$AP Rocky': 'rap',
#  'Travis Barker': 'rock',
#  'G Herbo': 'rap',
#  'Swae Lee': 'rap',
#  '2Pac': 'rap',
#  'King Von': 'rap',
#  '24kGoldn': 'rap',
#  '$NOT': 'rap',
#  'Sleepy Hallow': 'rap',
#  'Linkin Park': 'metal',
#  'Pooh Shiesty': 'rap',
#  'YNW Melly': 'rap',
#  '42 Dugg': 'rap',
#  'Young Stoner Life': 'rap',
#  'Dr. Dre': 'rap',
#  'Upchurch': 'country',
#  'The Notorious B.I.G.': 'rap',
#  'Lil Mosey': 'rap',
#  'Lil Darkie': 'rap',
#  'Young Dolph': 'rap',
#  'Outkast': 'rap',
#  'Blueface': 'rap',
#  'Yung Gravy': 'rap',
#  'BROCKHAMPTON': 'rap',
#  'JID': 'rap',
#  'Shiloh Dynasty': 'rap',
#  'El Alfa': 'rap',
#  'Slipknot': 'metal',
#  'Powfu': 'rap',
#  'Key Glock': 'rap',
#  'Jelly Roll': 'country',
#  '6ix9ine': 'rap',
#  'System Of A Down': 'metal',
#  'Disturbed': 'metal',
#  'DDG': 'rap',
#  'Ice Cube': 'rap',
#  'Nas': 'rap',
#  'Joey Bada$$': 'rap',
#  'Comethazine': 'rap',
#  'Cochise': 'rap',
#  'Pi’erre Bourne': 'rap',
#  'Tee Grizzley': 'rap',
#  'Vince Staples': 'rap',
#  'Boosie Badazz': 'rap',
#  'Papa Roach': 'metal',
#  'SpotemGottem': 'rap',
#  'Ghostemane': 'rap',
#  'Sheff G': 'rap',
#  'Coi Leray': 'r&b',
#  'Shoreline Mafia': 'rap',
#  'Lil Tracy': 'rap',
#  'YBN Nahmir': 'rap',
#  'Korn': 'metal',
#  'Denzel Curry': 'rap',
#  'Steve Lacy': 'r&b',
#  'CORPSE': 'rap',
#  'MF DOOM': 'rap',
#  'BONES': 'rap',
#  'Tom MacDonald': 'country',
#  'BIA': 'r&b',
#  'Young Nudy': 'rap',
#  'Pouya': 'rap',
#  'Waka Flocka Flame': 'rap',
#  'iamjakehill': 'rap',
#  'CJ': 'rap',
#  'Josh A': 'rap',
#  'Twista': 'rap',
#  'OHGEESY': 'rap',
#  'MO3': 'rap',
#  'Yungeen Ace': 'rap',
#  'Beastie Boys': 'rock',
#  'Curren$y': 'rap',
#  'Baby Keem': 'rap',
#  'Godsmack': 'metal',
#  'Smino': 'r&b',
#  'Rage Against The Machine': 'metal',
#  'Mozzy': 'rap',
#  'Freddie Gibbs': 'rap',
#  'GoldLink': 'soul',
#  'Deftones': 'indie',
#  'Only The Family': 'rap',
#  'Tyla Yaweh': 'rap',
#  'Dreamville': 'rap',
#  '1nonly': 'rap',
#  'Plies': 'rap',
#  'Bankrol Hayden': 'rap',
#  'Isaiah Rashad': 'rap',
#  'Too $hort': 'rap',
#  'Money Man': 'rap',
#  'Bone Thugs-N-Harmony': 'rap',
#  'Lil Dicky': 'rap',
#  'Rich Homie Quan': 'rap',
#  'SadBoyProlific': 'rap',
#  'Mike WiLL Made-It': 'rap',
#  'EARTHGANG': 'rap',
#  'IDK': 'rap',
#  'Lupe Fiasco': 'rap',
#  'Gera MX': 'rap',
#  'DJ Drama': 'rap',
#  'Fat Joe': 'rap',
#  'Fenix Flexin': 'rap',
#  'Tay-K': 'rap',
#  'Quando Rondo': 'rap',
#  'Wyclef Jean': 'rap',
#  'JACKBOYS': 'rap',
#  'Skepta': 'rap',
#  'Remble': 'rap',
#  'Adam Calhoun': 'country',
#  'Kota the Friend': 'rap',
#  'Chris Webby': 'indie',
#  'Lil Loaded': 'rap',
#  'ilyTOMMY': 'rap',
#  'MadeinTYO': 'rap',
#  'Kina': 'rap',
#  'Young Money': 'rap',
#  'Saba': 'r&b',
#  'Lil Pump': 'rap',
#  'South Park Mexican': 'rap',
#  'khai dreams': 'rap',
#  'Night Lovell': 'rap',
#  'Limp Bizkit': 'metal',
#  'Savage Ga$p': 'rap',
#  'J.I the Prince of N.Y': 'r&b',
#  '03 Greedo': 'rap',
#  'JayDaYoungan': 'rap',
#  'Drakeo the Ruler': 'rap',
#  'Yung Joc': 'rap',
#  'A Tribe Called Quest': 'jazz',
#  'Earl Sweatshirt': 'rap',
#  'Theory of a Deadman': 'metal',
#  'Social House': 'rap',
#  'Phora': 'r&b',
#  'DJ Scheme': 'rap',
#  'TOKYO’S REVENGE': 'rap',
#  'Hotboii': 'rap',
#  'Method Man': 'rap',
#  'Colt Ford': 'rock',
#  'MC Virgins': 'rap',
#  'YFN Lucci': 'r&b',
#  'Wu-Tang Clan': 'rap',
#  'Baby Bash': 'dance',
#  'Snøw': 'rap',
#  'Ying Yang Twins': 'dance',
#  'Sada Baby': 'rap',
#  "Lil' Kim": 'dance',
#  'Jadakiss': 'rap',
#  'Lund': 'rap',
#  'Calboy': 'rap',
#  'Shy Glizzy': 'rap',
#  'Struggle Jennings': 'country',
#  'Cypress Hill': 'rap',
#  'Staind': 'metal',
#  'Flipp Dinero': 'rap',
#  'Berner': 'rap',
#  'Dax': 'rap',
#  'Eve': 'dance',
#  'Larry June': 'rap',
#  'Juelz Santana': 'rap',
#  'Three 6 Mafia': 'rap',
#  'Smokepurpp': 'rap',
#  'Lil Jon & The East Side Boyz': 'rap',
#  'Birdman': 'rap',
#  'Mase': 'rap',
#  'Swizz Beatz': 'rap',
#  'Mariah Angeliq': 'rap',
#  'Ace Hood': 'rap',
#  'Landon Cube': 'rap',
#  'Paul Wall': 'rap',
#  'DeJ Loaf': 'r&b',
#  'gnash': 'indie',
#  'Benny The Butcher': 'rap',
#  'Rxseboy': 'rap',
#  'Project Pat': 'rap',
#  'Ari Lennox': 'soul',
#  'Tion Wayne': 'rap',
#  'Fredo Bang': 'rap',
#  'The Alchemist': 'rap',
#  'Chevelle': 'metal',
#  'Warren G': 'rap',
#  'Dave East': 'rap',
#  'JUVENILE': 'rap',
#  'Lil Keed': 'rap',
#  'UGK': 'rap',
#  'Sage The Gemini': 'dance',
#  'Yung Pinch': 'rap',
#  'Desiigner': 'rap',
#  'Xavier Wulf': 'rap',
#  'nothing,nowhere.': 'rock',
#  'VIC MENSA': 'rap',
#  'The Lacs': 'country',
#  'tobi lou': 'r&b',
#  'Rowdy Rebel': 'rap',
#  'Shotgun Willy': 'rap',
#  '347aidan': 'rap',
#  'DaniLeigh': 'r&b',
#  'Clever': 'rap',
#  'August Alsina': 'r&b',
#  'lilbubblegum': 'rap',
#  '311': 'metal',
#  'Common': 'soul',
#  'Bladee': 'rap',
#  'Jay Park': 'r&b',
#  'Will Smith': 'dance',
#  'Eazy-E': 'rap',
#  'SiR': 'soul',
#  'Sik World': 'rap',
#  'Dom Kennedy': 'rap',
#  'Domo Genesis': 'rap',
#  'Krizz Kaliko': 'country',
#  'Blanco Brown': 'country',
#  'Aries': 'rap',
#  'Roscoe Dash': 'rap',
#  'Bun B': 'rap',
#  'Luh Kel': 'r&b',
#  '112': 'dance',
#  'Slim Thug': 'rap',
#  'StaySolidRocky': 'rap',
#  '3OH!3': 'dance',
#  'Lloyd Banks': 'rap',
#  'Shelley FKA DRAM': 'r&b',
#  'Buddy': 'r&b',
#  'Famous Dex': 'rap',
#  'guardin': 'rap',
#  'Shordie Shordie': 'rap',
#  'Hit-Boy': 'rap',
#  'Cam’ron': 'rap',
#  'D12': 'rap',
#  'Insane Clown Posse': 'rock',
#  'Snow Tha Product': 'rap',
#  'Hobo Johnson': 'rap',
#  'Chloe x Halle': 'dance',
#  'Taio Cruz': 'edm',
#  'N.W.A.': 'rap',
#  'Mooski': 'rap',
#  'Agust D': 'rap',
#  'Big K.R.I.T.': 'rap',
#  'Rittz': 'country',
#  'Fugees': 'rap',
#  'NoCap': 'rap',
#  'Redman': 'rap',
#  'LMFAO': 'edm',
#  'Ryan Caraveo': 'indie',
#  'Young Buck': 'rap',
#  'Guapdad 4000': 'soul',
#  'Kurupt': 'rap',
#  'Sheck Wes': 'rap',
#  'Styles P': 'rap',
#  'Saliva': 'metal',
#  'Nedarb': 'rap',
#  'Scorey': 'rap',
#  'Puddle Of Mudd': 'metal',
#  'KIDS SEE GHOSTS': 'rap',
#  'Mobb Deep': 'rap',
#  'Jasiah': 'rap',
#  'Cazzu': 'rap',
#  'MOD SUN': 'rock',
#  'LPB Poody': 'rap',
#  'Big Scarr': 'rap',
#  'BabyJake': 'rap',
#  'Action Bronson': 'rap',
#  'Trick Daddy': 'rap',
#  'Y2K': 'rap',
#  'Travis Porter': 'rap',
#  'Z-Ro': 'rap',
#  'Roy Woods': 'soul',
#  'Felix Jaehn': 'house',
#  'Brandy': 'soul',
#  'Lil Eazzyy': 'rap',
#  'Witt Lowry': 'rap',
#  'Stone Sour': 'metal',
#  'Rustage': 'rap',
#  'Webbie': 'rap',
#  'Royce Da 5\'9"': 'rap',
#  'BJ The Chicago Kid': 'soul',
#  'King Lil G': 'rap',
#  'dvsn': 'soul',
#  'Bobby Shmurda': 'rap',
#  'A$AP Mob': 'rap',
#  'Teqkoi': 'rap',
#  'Afroman': 'rap',
#  'Wifisfuneral': 'rap',
#  'Rochy RD': 'rap',
#  'Hoodie Allen': 'indie',
#  'Killstation': 'rap',
#  'glaive': 'rap',
#  'Joe': 'soul',
#  'Fatboibari': 'rap',
#  'Atreyu': 'metal',
#  'Coolio': 'rap',
#  'GASHI': 'soul',
#  'Tego Calderon': 'rap',
#  'THE SCOTTS': 'rap',
#  'Far East Movement': 'edm',
#  'Call Me Karizma': 'rap',
#  '22Gz': 'rap',
#  'Aaron May': 'rap',
#  'Christian French': 'rap',
#  'Skizzy Mars': 'indie',
#  'Pop Evil': 'metal',
#  'A Perfect Circle': 'metal',
#  'Jay Sean': 'dance',
#  'Mick Jenkins': 'rap',
#  'Darkoo': 'rap',
#  'BlocBoy JB': 'rap',
#  'Jay Critch': 'rap',
#  'RM': 'rap',
#  'Madvillain': 'rap',
#  'Futuristic': 'indie',
#  'Spinabenz': 'rap',
#  'Babyface Ray': 'rap',
#  'Mudvayne': 'metal',
#  'Xzibit': 'rap',
#  'Kelly Rowland': 'soul',
#  'Stevie Wonder': 'soul',
#  'ROSALÍA': 'r&b',
#  'Marvin Gaye': 'soul',
#  'Masego': 'soul',
#  'Dalex': 'r&b',
#  'Fana Hues': 'indie',
#  'Lucky Daye': 'indie',
#  'Majid Jordan': 'soul',
#  'Omar Apollo': 'soul',
#  'Vedo': 'r&b',
#  'Syd': 'soul',
#  'Cautious Clay': 'indie',
#  'Estelle': 'soul',
#  'Sabrina Claudio': 'r&b',
#  'Janelle Monáe': 'soul',
#  'NIKI': 'r&b',
#  'UMI': 'soul',
#  'The-Dream': 'dance',
#  'MNEK': 'dance',
#  'Kirk Franklin': 'r&b',
#  '88rising': 'r&b',
#  'Erykah Badu': 'soul',
#  'Fousheé': 'indie',
#  'SG Lewis': 'soul',
#  'Duckwrth': 'soul',
#  'Janet Jackson': 'soul',
#  'Aloe Blacc': 'soul',
#  'Teyana Taylor': 'soul',
#  'Victoria Monét': 'dance',
#  'Peach Tree Rascals': 'indie',
#  'Mario': 'dance',
#  'Boyz II Men': 'r&b',
#  'Sonder': 'r&b',
#  'Mahalia': 'soul',
#  'Keri Hilson': 'soul',
#  'ODIE': 'indie',
#  'Mereba': 'soul',
#  'Kaash Paige': 'r&b',
#  'John K': 'indie',
#  'Dwele': 'soul',
#  'Sammie': 'r&b',
#  'Free Nationals': 'soul',
#  'Monica': 'soul',
#  'Jungle': 'soul',
#  'Solange': 'soul',
#  'Tierra Whack': 'soul',
#  'The Internet': 'soul',
#  'Bruno Major': 'indie',
#  'Emotional Oranges': 'indie',
#  'Hiatus Kaiyote': 'soul',
#  'DPR LIVE': 'r&b',
#  'Mac Ayres': 'soul',
#  'Crush': 'r&b',
#  'Tink': 'r&b',
#  'Ginuwine': 'soul',
#  'Omarion': 'dance',
#  'JoJo': 'dance',
#  'Tamia': 'soul',
#  'SoMo': 'dance',
#  'FKA twigs': 'dance',
#  'Layton Greene': 'r&b',
#  'Tank': 'r&b',
#  'Sevyn Streeter': 'soul',
#  'Robin Thicke': 'soul',
#  'HONNE': 'r&b',
#  'YK Osiris': 'r&b',
#  'Faith Evans': 'soul',
#  'Audrey Mika': 'r&b',
#  'Sinead Harnett': 'soul',
#  'Kelis': 'soul',
#  'Tems': 'r&b',
#  'Luther Vandross': 'soul',
#  'DEAN': 'r&b',
#  'Frankie J': 'dance',
#  'MarMar Oso': 'r&b',
#  'Blood Orange': 'soul',
#  'Raveena': 'soul',
#  'Nao': 'soul',
#  'Keith Sweat': 'soul',
#  'THEY.': 'soul',
#  "D'Angelo": 'soul',
#  'Bobby V.': 'r&b',
#  '070 Shake': 'r&b',
#  'BANKS': 'soul',
#  'Charlotte Day Wilson': 'soul',
#  'Anthony Hamilton': 'soul',
#  'Mýa': 'soul',
#  'Rotimi': 'r&b',
#  'Zak Abel': 'r&b',
#  'pH-1': 'r&b',
#  'Charlie Wilson': 'soul',
#  'Healy': 'indie',
#  'Corinne Bailey Rae': 'soul',
#  'SWV': 'soul',
#  'Jagged Edge': 'soul',
#  'Alex Isley': 'soul',
#  'Xavier Omär': 'soul',
#  'SAYGRACE': 'dance',
#  'Amber Mark': 'soul',
#  'Kash Doll': 'r&b',
#  'Bow Wow': 'dance',
#  'Trina': 'r&b',
#  'Mariah the Scientist': 'r&b',
#  'Terrace Martin': 'soul',
#  'Toni Braxton': 'soul',
#  'Pia Mia': 'dance',
#  'Remy Ma': 'r&b',
#  'Galimatias': 'soul',
#  'Yeek': 'indie',
#  'Justine Skye': 'r&b',
#  'VanJess': 'soul',
#  'Serena Isioma': 'indie',
#  'Jinsang': 'r&b',
#  'Musiq Soulchild': 'soul',
#  'Blackstreet': 'soul',
#  'Leven Kali': 'soul',
#  'Syleena Johnson': 'soul',
#  'Lakeyah': 'r&b',
#  'Jill Scott': 'soul',
#  'Ray J': 'r&b',
#  'Gallant': 'r&b',
#  'Fantasia': 'soul',
#  'Robert Glasper': 'soul',
#  'Jordin Sparks': 'dance',
#  'Jelani Aryeh': 'soul',
#  'Rexx Life Raj': 'soul',
#  'DRAMA': 'soul',
#  'Yuna': 'r&b',
#  'Sampha': 'soul',
#  'Rubi Rose': 'r&b',
#  'Ann Marie': 'r&b',
#  'Little Dragon': 'electronic',
#  'RINI': 'soul',
#  'Knxwledge': 'soul',
#  'Jean Deaux': 'soul',
#  'Dreezy': 'r&b',
#  'Fiji Blue': 'r&b',
#  'Avant': 'soul',
#  'Kalan.FrFr': 'r&b',
#  'Maxwell': 'soul',
#  'HEIZE': 'r&b',
#  'Cleo Sol': 'soul',
#  'K-Ci & JoJo': 'r&b',
#  'Tyrese': 'soul',
#  'Nicki Nicole': 'r&b',
#  'Arin Ray': 'soul',
#  'ZICO': 'r&b',
#  'Ant Clemons': 'r&b',
#  'AUDREY NUNA': 'indie',
#  'India.Arie': 'soul',
#  'Rels B': 'r&b',
#  'BIBI': 'r&b',
#  'Noname': 'soul',
#  'Arlo Parks': 'soul',
#  'Chrisette Michele': 'soul',
#  'Aaliyah': 'soul',
#  'New Edition': 'r&b',
#  ...}

# %%
# convert artists dictionary into a df
artists_df = pd.DataFrame(list(artists.items()),columns = ['artist','genre'])

# %%
artists_df.head()
# Out:
#            artist  genre
# 0           Drake    rap
# 1  Olivia Rodrigo    pop
# 2        Doja Cat  dance
# 3    Taylor Swift    pop
# 4   Justin Bieber    pop

# %%
artists_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5267 entries, 0 to 5266
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  5267 non-null   object
#  1   genre   5267 non-null   object
# dtypes: object(2)
# memory usage: 82.4+ KB

# %%
# check for duplicate artists
duplicate_artists = artists_df[artists_df.duplicated()]

# %%
duplicate_artists
# Out:
# Empty DataFrame
# Columns: [artist, genre]
# Index: []

# %%
# double check with different method
artists_df['artist'].is_unique
# Out:
# True

# %% [markdown]
# ----
#
# There is no duplicate artist in the dataframe and we have a total of **5267 artists** across **15 music genres**.
#
# ----

# %% [markdown]
# ## 2. Albums by Artist

# %% [markdown]
# We'll now pull the albums created by the 5267 seed artists.

# %%
limit = 5

albums_all = []
album_one_artist_df = pd.DataFrame(columns =['album_name', 'album_uri', 'num_tracks','artist_name']) # empty df
albums_all_df = pd.DataFrame(columns=['album_name','album_uri','num_tracks','artist_name']) # empty df

def get_albums_by_artist(artist):
    '''
    Given an artist, return a list of albums released
    by that artist.
    Retrieve album name, album uri, number of tracks,
    and artist name.
    Save results to a dataframe.
    '''
    for i in range(0,10,5):
        albums_results = sp.search(q='artist:'+str(artist), type='album',limit=limit,offset=i) 
        for j in range(0,len(albums_results['albums']['items'])-1): 
            album_name = albums_results['albums']['items'][j]['name']
            album_uri = albums_results['albums']['items'][j]['uri']
            album_tracks_num = albums_results['albums']['items'][j]['total_tracks']
            artist_name = albums_results['albums']['items'][j]['artists'][0]['name']
            album_one = [album_name, album_uri, album_tracks_num, artist_name]
            albums_all.append(album_one)
            
    album_temp = pd.DataFrame(albums_all, columns =['album_name', 'album_uri', 'num_tracks','artist_name'])    
    global album_one_artist_df
    album_one_artist_df = pd.concat([album_one_artist_df,album_temp])
    
    pass

def get_albums_all_artists(artists_obj):
    '''
    Given an object containint a list of artists, 
    return a list of albums released by those artist.
    Retrieve album name, album uri, number of tracks,
    and artist name.
    Save results to a dataframe.
    '''
    for artist in artists_obj:
        try:
            get_albums_by_artist(artist)
            global album_one_artist_df
            global albums_all_df
            albums_all_df = pd.concat([albums_all_df,album_one_artist_df.reset_index(drop=True)])
            album_one_artist_df = album_one_artist_df.iloc[0:0]
        except:
            pass
    
    return albums_all_df

# %%
# transform artist dictionary keys into a list including all the artists' names
artists_list = list(artists.keys())

# %%
# retrieve all the albums from the selected artists
get_albums_all_artists(artists_list)
# Out:
#                                               album_name  \
# 0                                          Scary Hours 2
# 1                                               Scorpion
# 2                                                  Views
# 3                                              More Life
# 4                                   Dark Lane Demo Tapes
# ...                                                  ...
# 40262                                             Mother
# 40263                                      Emerald Isles
# 40264                                           Panorama
# 40265                                      Mindful Sleep
# 40266  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                   album_uri num_tracks         artist_name
# 0      spotify:album:5LuoozUhs2pl3glZeAJl89          3               Drake
# 1      spotify:album:1ATL5GLyefJaxhQzSPVrLX         25               Drake
# 2      spotify:album:40GMAhriYJRO1rsY4YdrZb         20               Drake
# 3      spotify:album:1lXY618HWkwYKJWBRYR4MK         22               Drake
# 4      spotify:album:6OQ9gBfg5EXeNAEwGSs6jK         14               Drake
# ...                                     ...        ...                 ...
# 40262  spotify:album:28IlwCwIt69Xh627BwUC8F         14      In This Moment
# 40263  spotify:album:1KjGAHeyl9kHti8Z6ZT1pd          1  Moments of Clarity
# 40264  spotify:album:4ZaeYUM5vgvkpexijZ3w2r         13                Møme
# 40265  spotify:album:2kFyWqR5s7lvq8uNYGx6mj          3  Moments of Clarity
# 40266  spotify:album:2vS8ldvz5bk6aJ5HAYMBMw         18      In This Moment
#
# [107019615 rows x 4 columns]

# %%
# reset index
albums_all_df = albums_all_df.reset_index(drop=True)

# %%
albums_all_df
# Out:
#                                                   album_name  \
# 0                                              Scary Hours 2
# 1                                                   Scorpion
# 2                                                      Views
# 3                                                  More Life
# 4                                       Dark Lane Demo Tapes
# ...                                                      ...
# 107019610                                             Mother
# 107019611                                      Emerald Isles
# 107019612                                           Panorama
# 107019613                                      Mindful Sleep
# 107019614  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                       album_uri num_tracks         artist_name
# 0          spotify:album:5LuoozUhs2pl3glZeAJl89          3               Drake
# 1          spotify:album:1ATL5GLyefJaxhQzSPVrLX         25               Drake
# 2          spotify:album:40GMAhriYJRO1rsY4YdrZb         20               Drake
# 3          spotify:album:1lXY618HWkwYKJWBRYR4MK         22               Drake
# 4          spotify:album:6OQ9gBfg5EXeNAEwGSs6jK         14               Drake
# ...                                         ...        ...                 ...
# 107019610  spotify:album:28IlwCwIt69Xh627BwUC8F         14      In This Moment
# 107019611  spotify:album:1KjGAHeyl9kHti8Z6ZT1pd          1  Moments of Clarity
# 107019612  spotify:album:4ZaeYUM5vgvkpexijZ3w2r         13                Møme
# 107019613  spotify:album:2kFyWqR5s7lvq8uNYGx6mj          3  Moments of Clarity
# 107019614  spotify:album:2vS8ldvz5bk6aJ5HAYMBMw         18      In This Moment
#
# [107019615 rows x 4 columns]

# %% [markdown]
# > More than 100 million albums seem quite a large number for 5267 unique artists. My intuition leads me to think that **duplicate albums** have been pulled from the API.

# %%
# check unique number of artists
len(pd.unique(albums_all_df['album_name']))
# Out:
# 35135

# %%
# check unique number of artists
len(pd.unique(albums_all_df['album_uri']))
# Out:
# 39225

# %% [markdown]
# > A URI (Uniform Resource Indicator) is a unique identifier of an album. Looking at the unique URIs it's clear that we need to eliminate duplicate albums from the dataframe.

# %%
# check unique number of artists
len(pd.unique(albums_all_df['artist_name']))
# Out:
# 6745

# %% [markdown]
# > Interestingly, we also notice that there is a discrepancy between the 6745 resulting **number of unique artists** and the 5267 unique artists we started with.

# %% [markdown]
# We will start by first investigating the artists discrepancy issue and then by eliminating duplicate albumns.

# %% [markdown]
# ### Discrepancy in number of artists

# %% [markdown]
# Let's first check if the seed number of artists we started with (5267 unique artists) is a subset of the 6745 we find in the albumns dataframe.

# %%
# function to check difference between sets of artists
def check_artists_subset(artist_list_1,artist_list_2):
    artist_set_1 = set(artist_list_1)
    artist_set_2 = set(artist_list_2)
    print("There are {0} unique artists in the initial set".format(len(artist_set_1)))
    print("\nThere are {0} unique artists in the set of artists derived from pulling the albums".format(len(artist_set_2)))
    if artist_set_1.issubset(artist_set_2) is True:
        print("\nSeed set of artists is a subset of set of artists derived from pulling the albums")
    else:
        print("\nThe seed artist set has {0} artists that are not included in the artist set derived from pulling the albums".format(len(artist_set_1-artist_set_2)))
        print("\nThe artist set derived from pulling the albums has {0} artists that are not included in the seed artist set".format(len(artist_set_2-artist_set_1)))

# %%
# check difference between sets of artists
new_artists_list = albums_all_df['artist_name'].tolist()
check_artists_subset(artists_list,new_artists_list)
# Out:
# There are 5267 unique artists in the initial set
#
# There are 6745 unique artists in the set of artists derived from pulling the albums
#
# The seed artist set has 122 artists that are not included in the artist set derived from pulling the albums
#
# The artist set derived from pulling the albums has 1600 artists that are not included in the seed artist set

# %% [markdown]
# > The artists that we're really interested in are the seed 5267 unique artists that we pulled in the first step of our analysis. Therefore, we'll focus on those. Since the great majority of them are present in the newly created album dataset (only 122 artists from the seed set are missing), we will proceed  with **filtering the albums dataset for only the 5267 unique artists present in the seed set**.

# %%
# filter for seed artists
albums_all_df = albums_all_df[albums_all_df['artist_name'].isin(artists_list)]

# %%
# check number of artists is the 5267 (seed artists) - 122
len(set(albums_all_df['artist_name'].tolist()))
# Out:
# 5145

# %% [markdown]
# ### Eliminate duplicate albums

# %% [markdown]
# Let's now eliminate duplicate albums for the 5145 artists in our set.

# %%
albums_all_df = albums_all_df.drop_duplicates(subset=['album_uri'])

# %%
albums_all_df
# Out:
#                                                   album_name  \
# 0                                              Scary Hours 2
# 1                                                   Scorpion
# 2                                                      Views
# 3                                                  More Life
# 4                                       Dark Lane Demo Tapes
# ...                                                      ...
# 106939088                                      Perfect Ghost
# 106979341                          Boasty (feat. Idris Elba)
# 106979346         My One (feat. Tory Lanez, Kranium & Dappy)
# 107019612                                           Panorama
# 107019614  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                       album_uri num_tracks     artist_name
# 0          spotify:album:5LuoozUhs2pl3glZeAJl89          3           Drake
# 1          spotify:album:1ATL5GLyefJaxhQzSPVrLX         25           Drake
# 2          spotify:album:40GMAhriYJRO1rsY4YdrZb         20           Drake
# 3          spotify:album:1lXY618HWkwYKJWBRYR4MK         22           Drake
# 4          spotify:album:6OQ9gBfg5EXeNAEwGSs6jK         14           Drake
# ...                                         ...        ...             ...
# 106939088  spotify:album:7BRmBGQ4t1kMYpNUgsv1OL          2            Myon
# 106979341  spotify:album:7JoyVaXzxpgTPjkgB8mWk3          1           Wiley
# 106979346  spotify:album:1bE9v4U6xT3MDCh2SPn3jH          1           Wiley
# 107019612  spotify:album:4ZaeYUM5vgvkpexijZ3w2r         13            Møme
# 107019614  spotify:album:2vS8ldvz5bk6aJ5HAYMBMw         18  In This Moment
#
# [36978 rows x 4 columns]

# %%
# check unique number of artists
len(pd.unique(albums_all_df['album_uri']))
# Out:
# 36978

# %% [markdown]
# ## 3. Tracks by Album

# %%
spotify = spotipy.Spotify(requests_timeout=100,retries=10)
from pandas.errors import MergeError

# function to extract tracks by album
def get_tracks_from_albums(list_of_albums_uri):
    
    '''
    For every album previously identified as 
    representative of a genre, find the list of tracks.
    
    Returns metadata for all tracks as well as music 
    features characterizing the tracks.
    
    Finally joins all data in one complete dataframe. 
    '''
    
    complete_tracks_df = pd.DataFrame() # empty df
    
    track_ids = []

    for album_uri in list_of_albums_uri:
        current_album_tracks = []
        album_id = album_uri.split(':')[2]
        album_results = sp.album(album_id) 

        for i in range(len(album_results['tracks']['items'])):
            track_id = album_results['tracks']['items'][i]['id']
            track_ids.append(track_id)
            current_album_tracks.append(track_id)

        track_meta={'id':[],'album_name':[], 'track_name':[], 
                       'artist_name':[],'explicit':[],'track_popularity':[]}
        
        for track_id in current_album_tracks:
            # get track's meta data
            meta = sp.track(track_id)
            
            # track id
            track_meta['id'].append(track_id)
            
            # album name
            album_name = meta['album']['name']
            track_meta['album_name']+=[album_name]

            # track name
            track_name = meta['name']
            track_meta['track_name']+=[track_name]

            # artist name
            s = ', '
            artist_name = s.join([artist['name'] for artist in meta['artists']])
            track_meta['artist_name']+=[artist_name]

            # explicit: lyrics could be considered offensive or unsuitable for children
            explicit = meta['explicit']
            track_meta['explicit'].append(explicit)

            # track popularity
            track_popularity = meta['popularity']
            track_meta['track_popularity'].append(track_popularity)

        # build a track metadata df 
        track_meta_df = pd.DataFrame.from_dict(track_meta) 

        # find track features and aggregate them in a df
        track_features = sp.audio_features(track_meta_df['id'])
        #print(len(track_features))
        try:
            track_features_df = pd.DataFrame.from_dict(track_features)
        except:
            pass
             
        try:
            # combine metadata and track features dataframes into one large dataframe
            tracks_df = track_meta_df.merge(track_features_df)
        except MergeError:
            pass
        
        complete_tracks_df = pd.concat([complete_tracks_df,tracks_df])
        
    return complete_tracks_df

# %%
# convert album_uri col into a list of uris
albums_uri_list = albums_all_df['album_uri'].tolist()

# %%
len(albums_uri_list)
# Out:
# 36978

# %%
# tracks_chunk_1 = get_tracks_from_albums(albums_uri_list[:2000])
# tracks_chunk_2 = get_tracks_from_albums(albums_uri_list[2000:2500])
# tracks_chunk_3 = get_tracks_from_albums(albums_uri_list[2500:5000])
# tracks_chunk_4 = get_tracks_from_albums(albums_uri_list[5000:7500])
# tracks_chunk_5 = get_tracks_from_albums(albums_uri_list[7500:10000])
# tracks_chunk_6 = get_tracks_from_albums(albums_uri_list[20000:22500])
tracks_chunk_7 = get_tracks_from_albums(albums_uri_list[22500:25000])

# %% [markdown]
# > **Note**: while trying to retrieve all the track data in one go, I keep running in a *timeout error*. After multiple tests on the code, I have decided to both increase the *requests_timeout* parameter to 100 and to pull the data in **<mark>chunks<mark/>**, running the process in parallel on **<mark>Jupyter Lab<mark/>** and **<mark>Google colab<mark/>** with GPU and high-RAM.

# %%
# Store list in pickle object so we can pull track data simultaneously on jupyter lab and colab without incurring in timeout error
with open('albums_uri_list.pkl', 'wb') as f:
    pickle.dump(albums_uri_list, f)

# %%
# upload colab chunk of track data
tracks_chunk_colab = pd.read_pickle('/Users/valentinarizzati/Desktop/GitStuff/Projects/Engineering-Spotify/final/track_colab.pkl')

# %%
# concatenate all chunks in one final df
tracks_all_df = pd.concat([tracks_chunk_1,tracks_chunk_2,
                           tracks_chunk_3,tracks_chunk_4,
                           tracks_chunk_5, tracks_chunk_6,
                           tracks_chunk_7,tracks_chunk_colab])

# %%
tracks_all_df
# Out:
#                         id                                         album_name  \
# 0   3aQem4jVGdhtg116TmJnHz                                      Scary Hours 2
# 1   65OVbaJR5O1RmwOQx0875b                                      Scary Hours 2
# 2   4FRW5Nza1Ym91BGV4nFWXI                                      Scary Hours 2
# 0   2yg9UN4eo5eMVJ7OB4RWj3                                           Scorpion
# 1   0TlLq3lA83rQOYtrqBqSct                                           Scorpion
# ..                     ...                                                ...
# 13  6VP69eiW8k8OVUjS2lBYKy  Rise of the Blood Legion- The Best of (Chapter 1)
# 14  3GrFAJiT7FWRBKuLqVHy3b  Rise of the Blood Legion- The Best of (Chapter 1)
# 15  326QxhmInOvbgbaNzeHxRz  Rise of the Blood Legion- The Best of (Chapter 1)
# 16  5hamZeMqIFSZbEgQ2kQ9IN  Rise of the Blood Legion- The Best of (Chapter 1)
# 17  2IL0nY8qA8iju2TcADefUM  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                   track_name       artist_name  explicit  \
# 0                                What’s Next             Drake      True
# 1           Wants and Needs (feat. Lil Baby)   Drake, Lil Baby      True
# 2   Lemon Pepper Freestyle (feat. Rick Ross)  Drake, Rick Ross      True
# 0                                   Survival             Drake      True
# 1                                    Nonstop             Drake      True
# ..                                       ...               ...       ...
# 13                                Adrenalize    In This Moment     False
# 14                             It is Written    In This Moment      True
# 15                                      Burn    In This Moment     False
# 16                                     Whore    In This Moment      True
# 17                          The Blood Legion    In This Moment     False
#
#     track_popularity  danceability  energy  key  loudness  ...  \
# 0                 82         0.781   0.594    0    -6.959  ...
# 1                 89         0.578   0.449    1    -6.349  ...
# 2                 77         0.770   0.637    1    -5.530  ...
# 0                 59         0.555   0.596    9    -9.090  ...
# 1                 77         0.912   0.412    7    -8.074  ...
# ..               ...           ...     ...  ...       ...  ...
# 13                30         0.443   0.960    6    -3.933  ...
# 14                19         0.299   0.762    1   -15.699  ...
# 15                27         0.358   0.819    4    -5.256  ...
# 16                33         0.474   0.884    6    -3.845  ...
# 17                25         0.455   0.703    9    -7.147  ...
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.1620   0.0628  129.895  audio_features
# 1           0.000002    0.1190   0.1000  136.006  audio_features
# 2           0.000000    0.1710   0.4310   94.966  audio_features
# 0           0.000000    0.1230   0.1450   77.324  audio_features
# 1           0.012600    0.1040   0.4230  154.983  audio_features
# ..               ...       ...      ...      ...             ...
# 13          0.000000    0.1310   0.4320  132.190  audio_features
# 14          0.377000    0.6070   0.1570   80.819  audio_features
# 15          0.003870    0.1050   0.0452  146.093  audio_features
# 16          0.000000    0.0783   0.5240  179.559  audio_features
# 17          0.000047    0.1440   0.1250  149.816  audio_features
#
#                                      uri  \
# 0   spotify:track:3aQem4jVGdhtg116TmJnHz
# 1   spotify:track:65OVbaJR5O1RmwOQx0875b
# 2   spotify:track:4FRW5Nza1Ym91BGV4nFWXI
# 0   spotify:track:2yg9UN4eo5eMVJ7OB4RWj3
# 1   spotify:track:0TlLq3lA83rQOYtrqBqSct
# ..                                   ...
# 13  spotify:track:6VP69eiW8k8OVUjS2lBYKy
# 14  spotify:track:3GrFAJiT7FWRBKuLqVHy3b
# 15  spotify:track:326QxhmInOvbgbaNzeHxRz
# 16  spotify:track:5hamZeMqIFSZbEgQ2kQ9IN
# 17  spotify:track:2IL0nY8qA8iju2TcADefUM
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3aQem4jVGdht...
# 1   https://api.spotify.com/v1/tracks/65OVbaJR5O1R...
# 2   https://api.spotify.com/v1/tracks/4FRW5Nza1Ym9...
# 0   https://api.spotify.com/v1/tracks/2yg9UN4eo5eM...
# 1   https://api.spotify.com/v1/tracks/0TlLq3lA83rQ...
# ..                                                ...
# 13  https://api.spotify.com/v1/tracks/6VP69eiW8k8O...
# 14  https://api.spotify.com/v1/tracks/3GrFAJiT7FWR...
# 15  https://api.spotify.com/v1/tracks/326QxhmInOvb...
# 16  https://api.spotify.com/v1/tracks/5hamZeMqIFSZ...
# 17  https://api.spotify.com/v1/tracks/2IL0nY8qA8ij...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3aQe...      178154
# 1   https://api.spotify.com/v1/audio-analysis/65OV...      192956
# 2   https://api.spotify.com/v1/audio-analysis/4FRW...      383037
# 0   https://api.spotify.com/v1/audio-analysis/2yg9...      136187
# 1   https://api.spotify.com/v1/audio-analysis/0TlL...      238614
# ..                                                ...         ...
# 13  https://api.spotify.com/v1/audio-analysis/6VP6...      255653
# 14  https://api.spotify.com/v1/audio-analysis/3GrF...       30227
# 15  https://api.spotify.com/v1/audio-analysis/326Q...      284693
# 16  https://api.spotify.com/v1/audio-analysis/5ham...      245960
# 17  https://api.spotify.com/v1/audio-analysis/2IL0...      269173
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 0               4
# 1               4
# ..            ...
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
#
# [346636 rows x 23 columns]

# %%
# check concatenation was executed correctly

# list of track chunks pulled on jupyter lab
track_chunks = [tracks_chunk_1, tracks_chunk_2, tracks_chunk_3,
                tracks_chunk_4, tracks_chunk_5, tracks_chunk_6,
                tracks_chunk_7]
len_chunks = 0

for i in track_chunks:
    len_chunks += len(i)

len_chunks = len_chunks + len(tracks_chunk_colab) # add len of tracks data pulled on colab

if len(tracks_all_df) == len_chunks:
    print("Chunks concatenation executed correctly")
else:
    print("Not all records have been included in the concatenated dataframe")
# Out:
# Chunks concatenation executed correctly

# %%
# convert milliseconds to mins
# duration_ms: The duration of the track in milliseconds.
# 1 minute = 60 seconds = 60 × 1000 milliseconds = 60,000 ms
tracks_all_df['duration_mins'] = tracks_all_df['duration_ms']/60000

# %%
# reset index
tracks_all_df = tracks_all_df.reset_index(drop=True)

# %%
tracks_all_df.head()
# Out:
#                        id     album_name  \
# 0  3aQem4jVGdhtg116TmJnHz  Scary Hours 2
# 1  65OVbaJR5O1RmwOQx0875b  Scary Hours 2
# 2  4FRW5Nza1Ym91BGV4nFWXI  Scary Hours 2
# 3  2yg9UN4eo5eMVJ7OB4RWj3       Scorpion
# 4  0TlLq3lA83rQOYtrqBqSct       Scorpion
#
#                                  track_name       artist_name  explicit  \
# 0                               What’s Next             Drake      True
# 1          Wants and Needs (feat. Lil Baby)   Drake, Lil Baby      True
# 2  Lemon Pepper Freestyle (feat. Rick Ross)  Drake, Rick Ross      True
# 3                                  Survival             Drake      True
# 4                                   Nonstop             Drake      True
#
#    track_popularity  danceability  energy  key  loudness  ...  liveness  \
# 0                82         0.781   0.594    0    -6.959  ...     0.162
# 1                89         0.578   0.449    1    -6.349  ...     0.119
# 2                77         0.770   0.637    1    -5.530  ...     0.171
# 3                59         0.555   0.596    9    -9.090  ...     0.123
# 4                77         0.912   0.412    7    -8.074  ...     0.104
#
#    valence    tempo            type                                   uri  \
# 0   0.0628  129.895  audio_features  spotify:track:3aQem4jVGdhtg116TmJnHz
# 1   0.1000  136.006  audio_features  spotify:track:65OVbaJR5O1RmwOQx0875b
# 2   0.4310   94.966  audio_features  spotify:track:4FRW5Nza1Ym91BGV4nFWXI
# 3   0.1450   77.324  audio_features  spotify:track:2yg9UN4eo5eMVJ7OB4RWj3
# 4   0.4230  154.983  audio_features  spotify:track:0TlLq3lA83rQOYtrqBqSct
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3aQem4jVGdht...
# 1  https://api.spotify.com/v1/tracks/65OVbaJR5O1R...
# 2  https://api.spotify.com/v1/tracks/4FRW5Nza1Ym9...
# 3  https://api.spotify.com/v1/tracks/2yg9UN4eo5eM...
# 4  https://api.spotify.com/v1/tracks/0TlLq3lA83rQ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3aQe...      178154
# 1  https://api.spotify.com/v1/audio-analysis/65OV...      192956
# 2  https://api.spotify.com/v1/audio-analysis/4FRW...      383037
# 3  https://api.spotify.com/v1/audio-analysis/2yg9...      136187
# 4  https://api.spotify.com/v1/audio-analysis/0TlL...      238614
#
#   time_signature duration_mins
# 0              4      2.969233
# 1              4      3.215933
# 2              4      6.383950
# 3              4      2.269783
# 4              4      3.976900
#
# [5 rows x 24 columns]

# %%
# check if there are any null values
tracks_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346636 entries, 0 to 346635
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                346636 non-null  object
#  1   album_name        346636 non-null  object
#  2   track_name        346636 non-null  object
#  3   artist_name       346636 non-null  object
#  4   explicit          346636 non-null  bool
#  5   track_popularity  346636 non-null  int64
#  6   danceability      346636 non-null  float64
#  7   energy            346636 non-null  float64
#  8   key               346636 non-null  int64
#  9   loudness          346636 non-null  float64
#  10  mode              346636 non-null  int64
#  11  speechiness       346636 non-null  float64
#  12  acousticness      346636 non-null  float64
#  13  instrumentalness  346636 non-null  float64
#  14  liveness          346636 non-null  float64
#  15  valence           346636 non-null  float64
#  16  tempo             346636 non-null  float64
#  17  type              346636 non-null  object
#  18  uri               346636 non-null  object
#  19  track_href        346636 non-null  object
#  20  analysis_url      346636 non-null  object
#  21  duration_ms       346636 non-null  int64
#  22  time_signature    346636 non-null  int64
#  23  duration_mins     346636 non-null  float64
# dtypes: bool(1), float64(10), int64(5), object(8)
# memory usage: 61.2+ MB

# %% [markdown]
# > It looks like there are not null values. Let's double check with another method.

# %%
tracks_all_df.isnull().values.any()
# Out:
# False

# %%
tracks_all_df.isnull().sum()
# Out:
# id                  0
# album_name          0
# track_name          0
# artist_name         0
# explicit            0
# track_popularity    0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# duration_mins       0
# dtype: int64

# %% [markdown]
# > Great! After double checking with a couple of methods, we can state that there aren't **any null values**.

# %%
# check unique tracks based on their id
len(pd.unique(tracks_all_df['id']))
# Out:
# 346557

# %% [markdown]
# > By comparing the length of the df with the count of unique track ids, we notice that there are **duplicate tracks**. Let's eliminate them.

# %%
# drop duplicates
tracks_all_df = tracks_all_df.drop_duplicates(subset=['id'])

# %%
len(tracks_all_df)
# Out:
# 346557

# %% [markdown]
# > Great! Duplicate tracks have been eliminater and this is the final length of our tracks dataframe.

# %% [markdown]
# ## Save tables to SQL db

# %% [markdown]
# We will now store the three tables *artists*, *albums* and *tracks* in a SQL db instance. This will allow us to store the data permanently on a local machine for use in future analyses.

# %%
# initiate sqlalchemy and create engine
from sqlalchemy import create_engine
engine = create_engine('sqlite:////Users/valentinarizzati/Desktop/GitStuff/Projects/Engineering-Spotify/final/spotify.db', echo=False)

# %%
# create tables
with engine.begin() as connection:
    # create artists table
    artists_df.to_sql('artists', con=connection, if_exists='append')
    # create albums table
    albums_all_df.to_sql('albums', con=connection, if_exists='append')
    # create tracks table
    tracks_all_df.to_sql('tracks', con=connection, if_exists='append')

# %%
# check tables where created
engine.table_names()
# Out:
# ['albums', 'artists', 'tracks']

# %%
# check data was saved
pd.read_sql('SELECT * FROM artists;', engine)
# Out:
#       index             artist  genre
# 0         0              Drake    rap
# 1         1     Olivia Rodrigo    pop
# 2         2           Doja Cat  dance
# 3         3       Taylor Swift    pop
# 4         4      Justin Bieber    pop
# ...     ...                ...    ...
# 5262   5262              Jiony  house
# 5263   5263  The Toxic Avenger  house
# 5264   5264               Myon  house
# 5265   5265              Wiley  house
# 5266   5266               Møme  house
#
# [5267 rows x 3 columns]

# %%
# check data was saved
pd.read_sql('SELECT * FROM albums;', engine)
# Out:
#            index                                         album_name  \
# 0              0                                      Scary Hours 2
# 1              1                                           Scorpion
# 2              2                                              Views
# 3              3                                          More Life
# 4              4                               Dark Lane Demo Tapes
# ...          ...                                                ...
# 36973  106939088                                      Perfect Ghost
# 36974  106979341                          Boasty (feat. Idris Elba)
# 36975  106979346         My One (feat. Tory Lanez, Kranium & Dappy)
# 36976  107019612                                           Panorama
# 36977  107019614  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                   album_uri  num_tracks     artist_name
# 0      spotify:album:5LuoozUhs2pl3glZeAJl89           3           Drake
# 1      spotify:album:1ATL5GLyefJaxhQzSPVrLX          25           Drake
# 2      spotify:album:40GMAhriYJRO1rsY4YdrZb          20           Drake
# 3      spotify:album:1lXY618HWkwYKJWBRYR4MK          22           Drake
# 4      spotify:album:6OQ9gBfg5EXeNAEwGSs6jK          14           Drake
# ...                                     ...         ...             ...
# 36973  spotify:album:7BRmBGQ4t1kMYpNUgsv1OL           2            Myon
# 36974  spotify:album:7JoyVaXzxpgTPjkgB8mWk3           1           Wiley
# 36975  spotify:album:1bE9v4U6xT3MDCh2SPn3jH           1           Wiley
# 36976  spotify:album:4ZaeYUM5vgvkpexijZ3w2r          13            Møme
# 36977  spotify:album:2vS8ldvz5bk6aJ5HAYMBMw          18  In This Moment
#
# [36978 rows x 5 columns]

# %%
# check data was saved
pd.read_sql('SELECT * FROM tracks;', engine)
# Out:
#          index                      id  \
# 0            0  3aQem4jVGdhtg116TmJnHz
# 1            1  65OVbaJR5O1RmwOQx0875b
# 2            2  4FRW5Nza1Ym91BGV4nFWXI
# 3            3  2yg9UN4eo5eMVJ7OB4RWj3
# 4            4  0TlLq3lA83rQOYtrqBqSct
# ...        ...                     ...
# 346552  346631  6VP69eiW8k8OVUjS2lBYKy
# 346553  346632  3GrFAJiT7FWRBKuLqVHy3b
# 346554  346633  326QxhmInOvbgbaNzeHxRz
# 346555  346634  5hamZeMqIFSZbEgQ2kQ9IN
# 346556  346635  2IL0nY8qA8iju2TcADefUM
#
#                                                album_name  \
# 0                                           Scary Hours 2
# 1                                           Scary Hours 2
# 2                                           Scary Hours 2
# 3                                                Scorpion
# 4                                                Scorpion
# ...                                                   ...
# 346552  Rise of the Blood Legion- The Best of (Chapter 1)
# 346553  Rise of the Blood Legion- The Best of (Chapter 1)
# 346554  Rise of the Blood Legion- The Best of (Chapter 1)
# 346555  Rise of the Blood Legion- The Best of (Chapter 1)
# 346556  Rise of the Blood Legion- The Best of (Chapter 1)
#
#                                       track_name       artist_name  explicit  \
# 0                                    What’s Next             Drake         1
# 1               Wants and Needs (feat. Lil Baby)   Drake, Lil Baby         1
# 2       Lemon Pepper Freestyle (feat. Rick Ross)  Drake, Rick Ross         1
# 3                                       Survival             Drake         1
# 4                                        Nonstop             Drake         1
# ...                                          ...               ...       ...
# 346552                                Adrenalize    In This Moment         0
# 346553                             It is Written    In This Moment         1
# 346554                                      Burn    In This Moment         0
# 346555                                     Whore    In This Moment         1
# 346556                          The Blood Legion    In This Moment         0
#
#         track_popularity  danceability  energy  key  ...  liveness  valence  \
# 0                     82         0.781   0.594    0  ...    0.1620   0.0628
# 1                     89         0.578   0.449    1  ...    0.1190   0.1000
# 2                     77         0.770   0.637    1  ...    0.1710   0.4310
# 3                     59         0.555   0.596    9  ...    0.1230   0.1450
# 4                     77         0.912   0.412    7  ...    0.1040   0.4230
# ...                  ...           ...     ...  ...  ...       ...      ...
# 346552                30         0.443   0.960    6  ...    0.1310   0.4320
# 346553                19         0.299   0.762    1  ...    0.6070   0.1570
# 346554                27         0.358   0.819    4  ...    0.1050   0.0452
# 346555                33         0.474   0.884    6  ...    0.0783   0.5240
# 346556                25         0.455   0.703    9  ...    0.1440   0.1250
#
#           tempo            type                                   uri  \
# 0       129.895  audio_features  spotify:track:3aQem4jVGdhtg116TmJnHz
# 1       136.006  audio_features  spotify:track:65OVbaJR5O1RmwOQx0875b
# 2        94.966  audio_features  spotify:track:4FRW5Nza1Ym91BGV4nFWXI
# 3        77.324  audio_features  spotify:track:2yg9UN4eo5eMVJ7OB4RWj3
# 4       154.983  audio_features  spotify:track:0TlLq3lA83rQOYtrqBqSct
# ...         ...             ...                                   ...
# 346552  132.190  audio_features  spotify:track:6VP69eiW8k8OVUjS2lBYKy
# 346553   80.819  audio_features  spotify:track:3GrFAJiT7FWRBKuLqVHy3b
# 346554  146.093  audio_features  spotify:track:326QxhmInOvbgbaNzeHxRz
# 346555  179.559  audio_features  spotify:track:5hamZeMqIFSZbEgQ2kQ9IN
# 346556  149.816  audio_features  spotify:track:2IL0nY8qA8iju2TcADefUM
#
#                                                track_href  \
# 0       https://api.spotify.com/v1/tracks/3aQem4jVGdht...
# 1       https://api.spotify.com/v1/tracks/65OVbaJR5O1R...
# 2       https://api.spotify.com/v1/tracks/4FRW5Nza1Ym9...
# 3       https://api.spotify.com/v1/tracks/2yg9UN4eo5eM...
# 4       https://api.spotify.com/v1/tracks/0TlLq3lA83rQ...
# ...                                                   ...
# 346552  https://api.spotify.com/v1/tracks/6VP69eiW8k8O...
# 346553  https://api.spotify.com/v1/tracks/3GrFAJiT7FWR...
# 346554  https://api.spotify.com/v1/tracks/326QxhmInOvb...
# 346555  https://api.spotify.com/v1/tracks/5hamZeMqIFSZ...
# 346556  https://api.spotify.com/v1/tracks/2IL0nY8qA8ij...
#
#                                              analysis_url  duration_ms  \
# 0       https://api.spotify.com/v1/audio-analysis/3aQe...       178154
# 1       https://api.spotify.com/v1/audio-analysis/65OV...       192956
# 2       https://api.spotify.com/v1/audio-analysis/4FRW...       383037
# 3       https://api.spotify.com/v1/audio-analysis/2yg9...       136187
# 4       https://api.spotify.com/v1/audio-analysis/0TlL...       238614
# ...                                                   ...          ...
# 346552  https://api.spotify.com/v1/audio-analysis/6VP6...       255653
# 346553  https://api.spotify.com/v1/audio-analysis/3GrF...        30227
# 346554  https://api.spotify.com/v1/audio-analysis/326Q...       284693
# 346555  https://api.spotify.com/v1/audio-analysis/5ham...       245960
# 346556  https://api.spotify.com/v1/audio-analysis/2IL0...       269173
#
#        time_signature duration_mins
# 0                   4      2.969233
# 1                   4      3.215933
# 2                   4      6.383950
# 3                   4      2.269783
# 4                   4      3.976900
# ...               ...           ...
# 346552              4      4.260883
# 346553              4      0.503783
# 346554              4      4.744883
# 346555              4      4.099333
# 346556              4      4.486217
#
# [346557 rows x 25 columns]

# %% [markdown]
# > This looks great. All data about artists, albumns and tracks was stored locally.

# %% [markdown]
# ----
#
# By using a combination of Jupyter Lab and Google Colab to pull data from the Spotify API, we have now reached the **conclusion of the first step in our pipeline**.<br/>
# We will now proceed with data preprocessing and modeling in **<mark>notebook 02<mark/>** of this series.
#
# ----
